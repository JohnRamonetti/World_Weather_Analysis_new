# %%
# Import the dependencies.
import pandas as pd
#import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is uniques, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 785

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval        ")
print("--------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_weather = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_weather
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | mount isa
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | chuy
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | rio gallegos
# Processing Record 11 of Set 1 | vung tau
# Processing Record 12 of Set 1 | blatnica
# Processing Record 13 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | kholtoson
# Processing Record 16 of Set 1 | qaqortoq
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | esperance
# Processing Record 19 of Set 1 | flinders
# Processing Record 20 of Set 1 | sitka
# Processing Record 21 of Set 1 | port blair
# Processing Record 22 of Set 1 | rocha
# Processing Record 23 of Set 1 | sioux lookout
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | torbay
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | mezen
# Processing Record 29 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 1 | port hardy
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | cidreira
# Processing Record 33 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | aripuana
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | tezu
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | ostrovnoy
# Processing Record 42 of Set 1 | lucapa
# Processing Record 43 of Set 1 | tasiilaq
# Processing Record 44 of Set 1 | shache
# Processing Record 45 of Set 1 | riyadh
# Processing Record 46 of Set 1 | shaunavon
# Processing Record 47 of Set 1 | asau
# Processing Record 48 of Set 1 | sept-iles
# Processing Record 49 of Set 1 | nemuro
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 | lekoni
# Processing Record 2 of Set 2 | muisne
# Processing Record 3 of Set 2 | ilulissat
# Processing Record 4 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | pacific grove
# Processing Record 7 of Set 2 | redmond
# Processing Record 8 of Set 2 | san juan
# Processing Record 9 of Set 2 | cabo san lucas
# Processing Record 10 of Set 2 | ayer itam
# City not found. Skipping...
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | miraflores
# Processing Record 13 of Set 2 | oranjemund
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | inhambane
# Processing Record 16 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 2 | sumter
# Processing Record 18 of Set 2 | dawlatabad
# Processing Record 19 of Set 2 | thompson
# Processing Record 20 of Set 2 | sur
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | bereda
# Processing Record 23 of Set 2 | codrington
# Processing Record 24 of Set 2 | kushima
# Processing Record 25 of Set 2 | anar darreh
# City not found. Skipping...
# Processing Record 26 of Set 2 | narsaq
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | chabahar
# Processing Record 29 of Set 2 | busselton
# Processing Record 30 of Set 2 | olafsvik
# Processing Record 31 of Set 2 | kutahya
# Processing Record 32 of Set 2 | haimen
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | faanui
# Processing Record 35 of Set 2 | islamkot
# Processing Record 36 of Set 2 | manta
# Processing Record 37 of Set 2 | sheregesh
# Processing Record 38 of Set 2 | bengkulu
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | totma
# Processing Record 41 of Set 2 | lorengau
# Processing Record 42 of Set 2 | yakeshi
# Processing Record 43 of Set 2 | kushiro
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | ahipara
# Processing Record 46 of Set 2 | colares
# Processing Record 47 of Set 2 | kassiopi
# Processing Record 48 of Set 2 | bredasdorp
# Processing Record 49 of Set 2 | qaanaaq
# Processing Record 50 of Set 2 | pankrushikha
# Processing Record 1 of Set 3 | salalah
# Processing Record 2 of Set 3 | bluff
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | mahebourg
# Processing Record 5 of Set 3 | hilo
# Processing Record 6 of Set 3 | namatanai
# Processing Record 7 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 3 | santa marinella
# Processing Record 9 of Set 3 | bandarbeyla
# Processing Record 10 of Set 3 | yellowknife
# Processing Record 11 of Set 3 | khash
# Processing Record 12 of Set 3 | tuatapere
# Processing Record 13 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 3 | belyy yar
# Processing Record 15 of Set 3 | santa cruz
# Processing Record 16 of Set 3 | salisbury
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | cockburn town
# Processing Record 19 of Set 3 | lobez
# Processing Record 20 of Set 3 | clyde river
# Processing Record 21 of Set 3 | vaini
# Processing Record 22 of Set 3 | verkhnyaya inta
# Processing Record 23 of Set 3 | tongren
# Processing Record 24 of Set 3 | avarua
# Processing Record 25 of Set 3 | ornes
# Processing Record 26 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 3 | fortuna
# Processing Record 28 of Set 3 | morrope
# Processing Record 29 of Set 3 | prince rupert
# Processing Record 30 of Set 3 | karpogory
# Processing Record 31 of Set 3 | lakeside
# Processing Record 32 of Set 3 | phek
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | vardo
# Processing Record 35 of Set 3 | villazon
# Processing Record 36 of Set 3 | fairbanks
# Processing Record 37 of Set 3 | sambava
# Processing Record 38 of Set 3 | tiksi
# Processing Record 39 of Set 3 | soledad
# Processing Record 40 of Set 3 | ucluelet
# Processing Record 41 of Set 3 | katsuura
# Processing Record 42 of Set 3 | kidal
# Processing Record 43 of Set 3 | togur
# Processing Record 44 of Set 3 | upernavik
# Processing Record 45 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 3 | aykhal
# Processing Record 47 of Set 3 | nikolskoye
# Processing Record 48 of Set 3 | labuhan
# Processing Record 49 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 3 | gigmoto
# Processing Record 1 of Set 4 | bay roberts
# Processing Record 2 of Set 4 | oksfjord
# Processing Record 3 of Set 4 | evensk
# Processing Record 4 of Set 4 | balkanabat
# Processing Record 5 of Set 4 | saint-philippe
# Processing Record 6 of Set 4 | half moon bay
# Processing Record 7 of Set 4 | madarounfa
# Processing Record 8 of Set 4 | hay river
# Processing Record 9 of Set 4 | saint george
# Processing Record 10 of Set 4 | airai
# Processing Record 11 of Set 4 | buin
# Processing Record 12 of Set 4 | uarini
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | ilhabela
# Processing Record 15 of Set 4 | sorland
# Processing Record 16 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 17 of Set 4 | adrar
# Processing Record 18 of Set 4 | baie-comeau
# Processing Record 19 of Set 4 | beloha
# Processing Record 20 of Set 4 | cottonwood heights
# Processing Record 21 of Set 4 | burica
# City not found. Skipping...
# Processing Record 22 of Set 4 | hokitika
# Processing Record 23 of Set 4 | jertih
# Processing Record 24 of Set 4 | one hundred mile house
# City not found. Skipping...
# Processing Record 25 of Set 4 | arraial do cabo
# Processing Record 26 of Set 4 | santa cruz de tenerife
# Processing Record 27 of Set 4 | berdigestyakh
# Processing Record 28 of Set 4 | kavieng
# Processing Record 29 of Set 4 | duzce
# Processing Record 30 of Set 4 | ishigaki
# Processing Record 31 of Set 4 | vestmanna
# Processing Record 32 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 4 | george
# Processing Record 34 of Set 4 | sola
# Processing Record 35 of Set 4 | copiapo
# Processing Record 36 of Set 4 | beisfjord
# Processing Record 37 of Set 4 | umm lajj
# Processing Record 38 of Set 4 | luderitz
# Processing Record 39 of Set 4 | mujiayingzi
# Processing Record 40 of Set 4 | wlodawa
# Processing Record 41 of Set 4 | kaitangata
# Processing Record 42 of Set 4 | san quintin
# Processing Record 43 of Set 4 | mora
# Processing Record 44 of Set 4 | marfino
# Processing Record 45 of Set 4 | douentza
# Processing Record 46 of Set 4 | los llanos de aridane
# Processing Record 47 of Set 4 | nome
# Processing Record 48 of Set 4 | lavrentiya
# Processing Record 49 of Set 4 | constitucion
# Processing Record 50 of Set 4 | cananea
# Processing Record 1 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 5 | srednekolymsk
# Processing Record 3 of Set 5 | puerto leguizamo
# Processing Record 4 of Set 5 | alyangula
# Processing Record 5 of Set 5 | levelland
# Processing Record 6 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 7 of Set 5 | shreveport
# Processing Record 8 of Set 5 | pasian
# Processing Record 9 of Set 5 | dunedin
# Processing Record 10 of Set 5 | wanaka
# Processing Record 11 of Set 5 | chokurdakh
# Processing Record 12 of Set 5 | palmer
# Processing Record 13 of Set 5 | dekoa
# City not found. Skipping...
# Processing Record 14 of Set 5 | luwuk
# Processing Record 15 of Set 5 | dikson
# Processing Record 16 of Set 5 | praia
# Processing Record 17 of Set 5 | samarai
# Processing Record 18 of Set 5 | aiquile
# Processing Record 19 of Set 5 | havre-saint-pierre
# Processing Record 20 of Set 5 | faya
# Processing Record 21 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 5 | ponta do sol
# Processing Record 23 of Set 5 | olinda
# Processing Record 24 of Set 5 | geraldton
# Processing Record 25 of Set 5 | great yarmouth
# Processing Record 26 of Set 5 | tautira
# Processing Record 27 of Set 5 | ribeira grande
# Processing Record 28 of Set 5 | xuddur
# Processing Record 29 of Set 5 | alofi
# Processing Record 30 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 5 | sao filipe
# Processing Record 32 of Set 5 | ames
# Processing Record 33 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 5 | otwock
# Processing Record 35 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 36 of Set 5 | pochutla
# Processing Record 37 of Set 5 | nanortalik
# Processing Record 38 of Set 5 | mar del plata
# Processing Record 39 of Set 5 | sao miguel do araguaia
# Processing Record 40 of Set 5 | inuvik
# Processing Record 41 of Set 5 | saint-augustin
# Processing Record 42 of Set 5 | ancud
# Processing Record 43 of Set 5 | zhigansk
# Processing Record 44 of Set 5 | touros
# Processing Record 45 of Set 5 | la ronge
# Processing Record 46 of Set 5 | tignere
# Processing Record 47 of Set 5 | grindavik
# Processing Record 48 of Set 5 | te anau
# Processing Record 49 of Set 5 | umarizal
# Processing Record 50 of Set 5 | norman wells
# Processing Record 1 of Set 6 | abnub
# Processing Record 2 of Set 6 | arona
# Processing Record 3 of Set 6 | mumford
# Processing Record 4 of Set 6 | mulanje
# Processing Record 5 of Set 6 | shubarshi
# Processing Record 6 of Set 6 | korla
# Processing Record 7 of Set 6 | olavarria
# Processing Record 8 of Set 6 | saldanha
# Processing Record 9 of Set 6 | kendari
# Processing Record 10 of Set 6 | margate
# Processing Record 11 of Set 6 | areosa
# Processing Record 12 of Set 6 | rethimnon
# Processing Record 13 of Set 6 | porto novo
# Processing Record 14 of Set 6 | waipawa
# Processing Record 15 of Set 6 | natal
# Processing Record 16 of Set 6 | tuktoyaktuk
# Processing Record 17 of Set 6 | garden city
# Processing Record 18 of Set 6 | hovd
# Processing Record 19 of Set 6 | shimoda
# Processing Record 20 of Set 6 | tabou
# Processing Record 21 of Set 6 | namibe
# Processing Record 22 of Set 6 | guilin
# Processing Record 23 of Set 6 | liverpool
# Processing Record 24 of Set 6 | shingu
# Processing Record 25 of Set 6 | vila velha
# Processing Record 26 of Set 6 | carnarvon
# Processing Record 27 of Set 6 | talnakh
# Processing Record 28 of Set 6 | cayenne
# Processing Record 29 of Set 6 | ponta delgada
# Processing Record 30 of Set 6 | isangel
# Processing Record 31 of Set 6 | cabedelo
# Processing Record 32 of Set 6 | iralaya
# Processing Record 33 of Set 6 | koslan
# Processing Record 34 of Set 6 | azul
# Processing Record 35 of Set 6 | kavali
# Processing Record 36 of Set 6 | verkhnyaya sinyachikha
# Processing Record 37 of Set 6 | bardiyah
# Processing Record 38 of Set 6 | iwanai
# Processing Record 39 of Set 6 | brookhaven
# Processing Record 40 of Set 6 | murbad
# Processing Record 41 of Set 6 | iqaluit
# Processing Record 42 of Set 6 | klaksvik
# Processing Record 43 of Set 6 | lagoa
# Processing Record 44 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 6 | bilma
# Processing Record 46 of Set 6 | honningsvag
# Processing Record 47 of Set 6 | saint-joseph
# Processing Record 48 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 49 of Set 6 | bethel
# Processing Record 50 of Set 6 | amboasary
# Processing Record 1 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 3 of Set 7 | ossora
# Processing Record 4 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 7 | aswan
# Processing Record 6 of Set 7 | novo aripuana
# Processing Record 7 of Set 7 | buchmany
# Processing Record 8 of Set 7 | buala
# Processing Record 9 of Set 7 | richards bay
# Processing Record 10 of Set 7 | shakawe
# Processing Record 11 of Set 7 | arroyo
# Processing Record 12 of Set 7 | midleton
# Processing Record 13 of Set 7 | mackenzie
# Processing Record 14 of Set 7 | nortelandia
# Processing Record 15 of Set 7 | turayf
# Processing Record 16 of Set 7 | pemba
# Processing Record 17 of Set 7 | rakke
# Processing Record 18 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 7 | guaymas
# Processing Record 20 of Set 7 | padang
# Processing Record 21 of Set 7 | krasnoselskiy
# Processing Record 22 of Set 7 | ducheng
# Processing Record 23 of Set 7 | dingle
# Processing Record 24 of Set 7 | constantine
# Processing Record 25 of Set 7 | uk
# City not found. Skipping...
# Processing Record 26 of Set 7 | acajutla
# Processing Record 27 of Set 7 | teahupoo
# Processing Record 28 of Set 7 | kedrovyy
# Processing Record 29 of Set 7 | russell
# Processing Record 30 of Set 7 | biak
# Processing Record 31 of Set 7 | chilliwack
# Processing Record 32 of Set 7 | ajdabiya
# Processing Record 33 of Set 7 | cherskiy
# Processing Record 34 of Set 7 | belmonte
# Processing Record 35 of Set 7 | verkhnechusovskiye gorodki
# Processing Record 36 of Set 7 | nkhata bay
# Processing Record 37 of Set 7 | naron
# Processing Record 38 of Set 7 | goure
# Processing Record 39 of Set 7 | betsiamites
# Processing Record 40 of Set 7 | vadso
# Processing Record 41 of Set 7 | guanaja
# Processing Record 42 of Set 7 | joshimath
# Processing Record 43 of Set 7 | fare
# Processing Record 44 of Set 7 | tevaitoa
# Processing Record 45 of Set 7 | behbahan
# Processing Record 46 of Set 7 | hofn
# Processing Record 47 of Set 7 | lowestoft
# Processing Record 48 of Set 7 | mount gambier
# Processing Record 49 of Set 7 | hof
# Processing Record 50 of Set 7 | severo-kurilsk
# Processing Record 1 of Set 8 | misratah
# Processing Record 2 of Set 8 | yermish
# Processing Record 3 of Set 8 | pacifica
# Processing Record 4 of Set 8 | ramnagar
# Processing Record 5 of Set 8 | brumado
# Processing Record 6 of Set 8 | shebunino
# Processing Record 7 of Set 8 | aktash
# Processing Record 8 of Set 8 | leningradskiy
# Processing Record 9 of Set 8 | road town
# Processing Record 10 of Set 8 | kinablangan
# Processing Record 11 of Set 8 | zaragoza
# Processing Record 12 of Set 8 | esil
# Processing Record 13 of Set 8 | kayerkan
# Processing Record 14 of Set 8 | kon tum
# Processing Record 15 of Set 8 | lebu
# Processing Record 16 of Set 8 | baie-saint-paul
# Processing Record 17 of Set 8 | karratha
# Processing Record 18 of Set 8 | atasu
# Processing Record 19 of Set 8 | arrecife
# Processing Record 20 of Set 8 | tyukalinsk
# Processing Record 21 of Set 8 | iquitos
# Processing Record 22 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 8 | kumo
# Processing Record 24 of Set 8 | cairns
# Processing Record 25 of Set 8 | omboue
# Processing Record 26 of Set 8 | morant bay
# Processing Record 27 of Set 8 | beysehir
# Processing Record 28 of Set 8 | huilong
# Processing Record 29 of Set 8 | athens
# Processing Record 30 of Set 8 | ust-barguzin
# Processing Record 31 of Set 8 | alberdi
# Processing Record 32 of Set 8 | seoni malwa
# Processing Record 33 of Set 8 | port moresby
# Processing Record 34 of Set 8 | sampit
# Processing Record 35 of Set 8 | hami
# Processing Record 36 of Set 8 | springdale
# Processing Record 37 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 38 of Set 8 | mbala
# Processing Record 39 of Set 8 | saint anthony
# Processing Record 40 of Set 8 | itarema
# Processing Record 41 of Set 8 | tarakan
# Processing Record 42 of Set 8 | baherden
# Processing Record 43 of Set 8 | coihaique
# Processing Record 44 of Set 8 | lazaro cardenas
# Processing Record 45 of Set 8 | tigil
# Processing Record 46 of Set 8 | bonavista
# Processing Record 47 of Set 8 | dali
# Processing Record 48 of Set 8 | manono
# Processing Record 49 of Set 8 | daru
# Processing Record 50 of Set 8 | ambulu
# Processing Record 1 of Set 9 | leirvik
# Processing Record 2 of Set 9 | caxito
# Processing Record 3 of Set 9 | avera
# Processing Record 4 of Set 9 | kluang
# Processing Record 5 of Set 9 | bilibino
# Processing Record 6 of Set 9 | pontianak
# Processing Record 7 of Set 9 | provideniya
# Processing Record 8 of Set 9 | aguas verdes
# Processing Record 9 of Set 9 | segezha
# Processing Record 10 of Set 9 | yar-sale
# Processing Record 11 of Set 9 | san policarpo
# Processing Record 12 of Set 9 | yulara
# Processing Record 13 of Set 9 | isla mujeres
# Processing Record 14 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 9 | sinegorye
# Processing Record 16 of Set 9 | north bend
# Processing Record 17 of Set 9 | tabas
# Processing Record 18 of Set 9 | oksovskiy
# Processing Record 19 of Set 9 | lima
# Processing Record 20 of Set 9 | risalpur
# Processing Record 21 of Set 9 | mangrol
# Processing Record 22 of Set 9 | banda aceh
# Processing Record 23 of Set 9 | san borja
# Processing Record 24 of Set 9 | klyuchi
# Processing Record 25 of Set 9 | nouadhibou
# Processing Record 26 of Set 9 | vermillion
# Processing Record 27 of Set 9 | atar
# Processing Record 28 of Set 9 | bemidji
# Processing Record 29 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 9 | caravelas
# Processing Record 31 of Set 9 | carballo
# Processing Record 32 of Set 9 | payson
# Processing Record 33 of Set 9 | altus
# Processing Record 34 of Set 9 | nenjiang
# Processing Record 35 of Set 9 | labytnangi
# Processing Record 36 of Set 9 | la asuncion
# Processing Record 37 of Set 9 | kyzyl-suu
# Processing Record 38 of Set 9 | acapulco
# Processing Record 39 of Set 9 | krasnovishersk
# Processing Record 40 of Set 9 | salamiyah
# Processing Record 41 of Set 9 | kiisa
# Processing Record 42 of Set 9 | dumas
# Processing Record 43 of Set 9 | mucurici
# Processing Record 44 of Set 9 | kamaishi
# Processing Record 45 of Set 9 | canora
# Processing Record 46 of Set 9 | noumea
# Processing Record 47 of Set 9 | bhan
# Processing Record 48 of Set 9 | agropoli
# Processing Record 49 of Set 9 | mandalgovi
# Processing Record 50 of Set 9 | kamenka
# Processing Record 1 of Set 10 | cap malheureux
# Processing Record 2 of Set 10 | ukiah
# Processing Record 3 of Set 10 | ketchikan
# Processing Record 4 of Set 10 | san andres
# Processing Record 5 of Set 10 | nabire
# Processing Record 6 of Set 10 | waitati
# Processing Record 7 of Set 10 | gat
# Processing Record 8 of Set 10 | korem
# Processing Record 9 of Set 10 | monrovia
# Processing Record 10 of Set 10 | panukulan
# Processing Record 11 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 12 of Set 10 | xiamen
# Processing Record 13 of Set 10 | pisco
# Processing Record 14 of Set 10 | cabo rojo
# Processing Record 15 of Set 10 | bossangoa
# Processing Record 16 of Set 10 | bud
# Processing Record 17 of Set 10 | tawau
# Processing Record 18 of Set 10 | sao joao da barra
# Processing Record 19 of Set 10 | muravlenko
# Processing Record 20 of Set 10 | rudbar
# Processing Record 21 of Set 10 | nosy varika
# Processing Record 22 of Set 10 | zalantun
# Processing Record 23 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 24 of Set 10 | lompoc
# Processing Record 25 of Set 10 | jalor
# Processing Record 26 of Set 10 | eyrarbakki
# Processing Record 27 of Set 10 | kokkola
# Processing Record 28 of Set 10 | phan thiet
# Processing Record 29 of Set 10 | yetholm
# City not found. Skipping...
# Processing Record 30 of Set 10 | mizdah
# Processing Record 31 of Set 10 | angoram
# Processing Record 32 of Set 10 | vestmannaeyjar
# Processing Record 33 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 10 | hailin
# Processing Record 35 of Set 10 | gazli
# Processing Record 36 of Set 10 | marawi
# Processing Record 37 of Set 10 | sao felix do xingu
# Processing Record 38 of Set 10 | zorritos
# Processing Record 39 of Set 10 | glyadyanskoye
# Processing Record 40 of Set 10 | leh
# Processing Record 41 of Set 10 | sladkovo
# Processing Record 42 of Set 10 | papayal
# Processing Record 43 of Set 10 | laiagam
# City not found. Skipping...
# Processing Record 44 of Set 10 | noormarkku
# Processing Record 45 of Set 10 | kavaratti
# Processing Record 46 of Set 10 | meulaboh
# Processing Record 47 of Set 10 | shahdadkot
# Processing Record 48 of Set 10 | mirina
# City not found. Skipping...
# Processing Record 49 of Set 10 | murten
# Processing Record 50 of Set 10 | mandeville
# Processing Record 1 of Set 11 | camacha
# Processing Record 2 of Set 11 | fray bentos
# Processing Record 3 of Set 11 | ca mau
# Processing Record 4 of Set 11 | abha
# Processing Record 5 of Set 11 | gurupi
# Processing Record 6 of Set 11 | turukhansk
# Processing Record 7 of Set 11 | takoradi
# Processing Record 8 of Set 11 | weyburn
# Processing Record 9 of Set 11 | dongying
# Processing Record 10 of Set 11 | kolochava
# Processing Record 11 of Set 11 | rostaq
# City not found. Skipping...
# Processing Record 12 of Set 11 | lasa
# Processing Record 13 of Set 11 | north platte
# Processing Record 14 of Set 11 | eureka
# Processing Record 15 of Set 11 | goderich
# Processing Record 16 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 17 of Set 11 | aksarka
# Processing Record 18 of Set 11 | turkan
# Processing Record 19 of Set 11 | bonito
# Processing Record 20 of Set 11 | merrill
# Processing Record 21 of Set 11 | uruzgan
# Processing Record 22 of Set 11 | kununurra
# Processing Record 23 of Set 11 | chaa-khol
# City not found. Skipping...
# Processing Record 24 of Set 11 | omaruru
# Processing Record 25 of Set 11 | mahajanga
# Processing Record 26 of Set 11 | kota kinabalu
# Processing Record 27 of Set 11 | gazanjyk
# Processing Record 28 of Set 11 | hearst
# Processing Record 29 of Set 11 | vila franca do campo
# Processing Record 30 of Set 11 | hirna
# Processing Record 31 of Set 11 | balabac
# Processing Record 32 of Set 11 | saint-leu
# Processing Record 33 of Set 11 | cedar city
# Processing Record 34 of Set 11 | bathsheba
# Processing Record 35 of Set 11 | antalaha
# Processing Record 36 of Set 11 | porto murtinho
# Processing Record 37 of Set 11 | faro
# Processing Record 38 of Set 11 | mabaruma
# Processing Record 39 of Set 11 | samarinda
# Processing Record 40 of Set 11 | khorol
# Processing Record 41 of Set 11 | sol-iletsk
# Processing Record 42 of Set 11 | cookshire
# City not found. Skipping...
# Processing Record 43 of Set 11 | chapais
# Processing Record 44 of Set 11 | savannah bight
# Processing Record 45 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 46 of Set 11 | husavik
# Processing Record 47 of Set 11 | namtsy
# Processing Record 48 of Set 11 | cumberland
# Processing Record 49 of Set 11 | huarmey
# Processing Record 50 of Set 11 | denpasar
# Processing Record 1 of Set 12 | sainte-maxime
# Processing Record 2 of Set 12 | wanning
# Processing Record 3 of Set 12 | soe
# Processing Record 4 of Set 12 | urumqi
# Processing Record 5 of Set 12 | havelock
# Processing Record 6 of Set 12 | simbahan
# Processing Record 7 of Set 12 | mexico
# Processing Record 8 of Set 12 | mogadishu
# Processing Record 9 of Set 12 | bogorodskoye
# Processing Record 10 of Set 12 | witu
# Processing Record 11 of Set 12 | tagusao
# Processing Record 12 of Set 12 | dwarka
# Processing Record 13 of Set 12 | thetford mines
# Processing Record 14 of Set 12 | santa maria
# Processing Record 15 of Set 12 | portland
# Processing Record 16 of Set 12 | prabumulih
# Processing Record 17 of Set 12 | guerrero negro
# Processing Record 18 of Set 12 | santa isabel
# Processing Record 19 of Set 12 | nyurba
# Processing Record 20 of Set 12 | durazno
# Processing Record 21 of Set 12 | hat yai
# Processing Record 22 of Set 12 | bell ville
# Processing Record 23 of Set 12 | vao
# Processing Record 24 of Set 12 | mehriz
# Processing Record 25 of Set 12 | coahuayana
# Processing Record 26 of Set 12 | yabelo
# Processing Record 27 of Set 12 | mino
# Processing Record 28 of Set 12 | quelimane
# Processing Record 29 of Set 12 | praia da vitoria
# Processing Record 30 of Set 12 | tabarqah
# City not found. Skipping...
# Processing Record 31 of Set 12 | jaque
# Processing Record 32 of Set 12 | torres
# Processing Record 33 of Set 12 | lyubeshiv
# City not found. Skipping...
# Processing Record 34 of Set 12 | juneau
# Processing Record 35 of Set 12 | arrifes
# Processing Record 36 of Set 12 | haines junction
# Processing Record 37 of Set 12 | solton
# Processing Record 38 of Set 12 | choix
# Processing Record 39 of Set 12 | wewak
# Processing Record 40 of Set 12 | sabang
# Processing Record 41 of Set 12 | raudeberg
# Processing Record 42 of Set 12 | san patricio
# Processing Record 43 of Set 12 | chlorakas
# Processing Record 44 of Set 12 | hambantota
# Processing Record 45 of Set 12 | nara
# Processing Record 46 of Set 12 | ekibastuz
# Processing Record 47 of Set 12 | kahului
# Processing Record 48 of Set 12 | udachnyy
# Processing Record 49 of Set 12 | lovozero
# Processing Record 50 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 13 | axim
# Processing Record 2 of Set 13 | chokwe
# Processing Record 3 of Set 13 | tonneins
# Processing Record 4 of Set 13 | naze
# Processing Record 5 of Set 13 | tual
# Processing Record 6 of Set 13 | aklavik
# Processing Record 7 of Set 13 | luoyang
# Processing Record 8 of Set 13 | san luis
# Processing Record 9 of Set 13 | portree
# Processing Record 10 of Set 13 | brun
# Processing Record 11 of Set 13 | sikonge
# Processing Record 12 of Set 13 | vanimo
# Processing Record 13 of Set 13 | elko
# Processing Record 14 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 13 | tukrah
# Processing Record 16 of Set 13 | bechem
# Processing Record 17 of Set 13 | dothan
# Processing Record 18 of Set 13 | sosnovo
# Processing Record 19 of Set 13 | berlevag
# Processing Record 20 of Set 13 | hashtrud
# Processing Record 21 of Set 13 | alcudia
# Processing Record 22 of Set 13 | chimore
# Processing Record 23 of Set 13 | acarau
# Processing Record 24 of Set 13 | monte azul
# Processing Record 25 of Set 13 | caucaia
# Processing Record 26 of Set 13 | beringovskiy
# Processing Record 27 of Set 13 | kyotera
# Processing Record 28 of Set 13 | dicabisagan
# Processing Record 29 of Set 13 | souillac
# Processing Record 30 of Set 13 | ngunguru
# Processing Record 31 of Set 13 | sao borja
# Processing Record 32 of Set 13 | kadoma
# Processing Record 33 of Set 13 | muli
# Processing Record 34 of Set 13 | bonthe
# Processing Record 35 of Set 13 | rosetta
# Processing Record 36 of Set 13 | sorong
# Processing Record 37 of Set 13 | sokolo
# Processing Record 38 of Set 13 | da nang
# Processing Record 39 of Set 13 | ixtapa
# Processing Record 40 of Set 13 | viedma
# Processing Record 41 of Set 13 | minab
# Processing Record 42 of Set 13 | port-gentil
# Processing Record 43 of Set 13 | telimele
# Processing Record 44 of Set 13 | laguna
# Processing Record 45 of Set 13 | cortes
# Processing Record 46 of Set 13 | pak phanang
# Processing Record 47 of Set 13 | dourbali
# Processing Record 48 of Set 13 | hassleholm
# Processing Record 49 of Set 13 | amurzet
# Processing Record 50 of Set 13 | hualmay
# Processing Record 1 of Set 14 | gushikawa
# Processing Record 2 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 14 | mercedes
# Processing Record 4 of Set 14 | college
# Processing Record 5 of Set 14 | beidao
# Processing Record 6 of Set 14 | egvekinot
# Processing Record 7 of Set 14 | dawei
# Processing Record 8 of Set 14 | coffs harbour
# Processing Record 9 of Set 14 | khandyga
# Processing Record 10 of Set 14 | aligudarz
# Processing Record 11 of Set 14 | timra
# Processing Record 12 of Set 14 | malindi
# Processing Record 13 of Set 14 | fort nelson
# Processing Record 14 of Set 14 | portoferraio
# Processing Record 15 of Set 14 | general roca
# Processing Record 16 of Set 14 | batagay
# Processing Record 17 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 14 | esmeraldas
# Processing Record 19 of Set 14 | la ciotat
# Processing Record 20 of Set 14 | saint-pierre
# Processing Record 21 of Set 14 | puri
# Processing Record 22 of Set 14 | zabaykalsk
# Processing Record 23 of Set 14 | ust-maya
# Processing Record 24 of Set 14 | kuytun
# Processing Record 25 of Set 14 | puerto colombia
# Processing Record 26 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 27 of Set 14 | gayeri
# Processing Record 28 of Set 14 | busayra
# Processing Record 29 of Set 14 | bridlington
# Processing Record 30 of Set 14 | kingman
# Processing Record 31 of Set 14 | kaeo
# Processing Record 32 of Set 14 | merauke
# Processing Record 33 of Set 14 | agadez
# Processing Record 34 of Set 14 | chake chake
# Processing Record 35 of Set 14 | sobolevo
# Processing Record 36 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 14 | clarence town
# Processing Record 38 of Set 14 | monkey bay
# Processing Record 39 of Set 14 | mut
# Processing Record 40 of Set 14 | usinsk
# Processing Record 41 of Set 14 | veraval
# Processing Record 42 of Set 14 | hell
# Processing Record 43 of Set 14 | salinas
# Processing Record 44 of Set 14 | antsohihy
# Processing Record 45 of Set 14 | gamboma
# Processing Record 46 of Set 14 | kalabo
# Processing Record 47 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 14 | jacareacanga
# Processing Record 49 of Set 14 | jerantut
# Processing Record 50 of Set 14 | batagay-alyta
# Processing Record 1 of Set 15 | hobyo
# Processing Record 2 of Set 15 | panaba
# Processing Record 3 of Set 15 | jining
# Processing Record 4 of Set 15 | baj
# Processing Record 5 of Set 15 | pyatnitskoye
# Processing Record 6 of Set 15 | kanigoro
# Processing Record 7 of Set 15 | nurota
# Processing Record 8 of Set 15 | luanda
# Processing Record 9 of Set 15 | jinchang
# Processing Record 10 of Set 15 | huangmei
# Processing Record 11 of Set 15 | seymchan
# Processing Record 12 of Set 15 | teknaf
# Processing Record 13 of Set 15 | kudahuvadhoo
# Processing Record 14 of Set 15 | nkowakowa
# Processing Record 15 of Set 15 | vilhena
# Processing Record 16 of Set 15 | emerald
# Processing Record 17 of Set 15 | comodoro rivadavia
# Processing Record 18 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 15 | tazovskiy
# Processing Record 20 of Set 15 | edd
# Processing Record 21 of Set 15 | vilyuysk
# Processing Record 22 of Set 15 | mecca
# Processing Record 23 of Set 15 | makokou
# Processing Record 24 of Set 15 | sarangani
# Processing Record 25 of Set 15 | bulgan
# Processing Record 26 of Set 15 | zyryanka
# Processing Record 27 of Set 15 | seregno
# Processing Record 28 of Set 15 | seddon
# Processing Record 29 of Set 15 | yingzhong
# City not found. Skipping...
# Processing Record 30 of Set 15 | grand-santi
# Processing Record 31 of Set 15 | siva
# Processing Record 32 of Set 15 | nuuk
# Processing Record 33 of Set 15 | praxedis guerrero
# Processing Record 34 of Set 15 | camana
# Processing Record 35 of Set 15 | zhaodong
# Processing Record 36 of Set 15 | virginia beach
# Processing Record 37 of Set 15 | khorixas
# Processing Record 38 of Set 15 | jalu
# Processing Record 39 of Set 15 | trollhattan
# Processing Record 40 of Set 15 | port lincoln
# Processing Record 41 of Set 15 | barra
# Processing Record 42 of Set 15 | zhengjiatun
# Processing Record 43 of Set 15 | micheweni
# Processing Record 44 of Set 15 | abalak
# Processing Record 45 of Set 15 | moose factory
# Processing Record 46 of Set 15 | gizo
# Processing Record 47 of Set 15 | niono
# Processing Record 48 of Set 15 | bodden town
# Processing Record 49 of Set 15 | peleduy
# Processing Record 50 of Set 15 | casper
# Processing Record 1 of Set 16 | luxor
# Processing Record 2 of Set 16 | tzaneen
# Processing Record 3 of Set 16 | manbij
# Processing Record 4 of Set 16 | cascais
# Processing Record 5 of Set 16 | neutraubling
# Processing Record 6 of Set 16 | montes altos
# Processing Record 7 of Set 16 | moss vale
# Processing Record 8 of Set 16 | takaka
# Processing Record 9 of Set 16 | fukuma
# Processing Record 10 of Set 16 | bam
# Processing Record 11 of Set 16 | tikrit
# Processing Record 12 of Set 16 | yashkul
# Processing Record 13 of Set 16 | nanchang
# Processing Record 14 of Set 16 | wichita falls
# Processing Record 15 of Set 16 | matamoros
# Processing Record 16 of Set 16 | tomatlan
# Processing Record 17 of Set 16 | dinhata
# Processing Record 18 of Set 16 | belaya gora
# Processing Record 19 of Set 16 | mahibadhoo
# Processing Record 20 of Set 16 | mayo
# Processing Record 21 of Set 16 | jiwani
# Processing Record 22 of Set 16 | grand gaube
# Processing Record 23 of Set 16 | ornskoldsvik
# Processing Record 24 of Set 16 | grimari
# City not found. Skipping...
# Processing Record 25 of Set 16 | point pedro
# Processing Record 26 of Set 16 | bollnas
# Processing Record 27 of Set 16 | kushikino
# Processing Record 28 of Set 16 | lakatoro
# Processing Record 29 of Set 16 | yumen
# Processing Record 30 of Set 16 | tizimin
# Processing Record 31 of Set 16 | kanjiza
# Processing Record 32 of Set 16 | komsomolskiy
# Processing Record 33 of Set 16 | maumere
# Processing Record 34 of Set 16 | crib point
# Processing Record 35 of Set 16 | santa rosa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 726

# %%
# Add the API city data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   New Norfolk -42.7826  147.0587     53.01        60          38
# 1  Punta Arenas -53.1500  -70.9167     53.60        43           0
# 2      Hermanus -34.4187   19.2345     66.00        75         100
# 3       Mataura -46.1927  168.8643     51.01        98         100
# 4     Mount Isa -20.7333  139.5000     75.20        31           0
# 5       Ushuaia -54.8000  -68.3000     46.40        61          40
# 6          Chuy -33.6971  -53.4616     70.02        82          90
# 7         Kapaa  22.0752 -159.3190     73.40        68          75
# 8  Rio Gallegos -51.6226  -69.2181     59.00        25           0
# 9      Vung Tau  10.3460  107.0843     79.34        82          40
#
#    Wind Speed Country Current Description
# 0        3.00      AU    scattered clouds
# 1       18.41      CL           clear sky
# 2        3.00      ZA     overcast clouds
# 3        2.30      NZ     overcast clouds
# 4       13.80      AU           clear sky
# 5       29.93      AR    scattered clouds
# 6        6.58      UY     overcast clouds
# 7       18.41      US       broken clouds
# 8       18.41      AR           clear sky
# 9       14.27      VN    scattered clouds

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   New Norfolk      AU -42.7826  147.0587     53.01        60          38
# 1  Punta Arenas      CL -53.1500  -70.9167     53.60        43           0
# 2      Hermanus      ZA -34.4187   19.2345     66.00        75         100
# 3       Mataura      NZ -46.1927  168.8643     51.01        98         100
# 4     Mount Isa      AU -20.7333  139.5000     75.20        31           0
# 5       Ushuaia      AR -54.8000  -68.3000     46.40        61          40
# 6          Chuy      UY -33.6971  -53.4616     70.02        82          90
# 7         Kapaa      US  22.0752 -159.3190     73.40        68          75
# 8  Rio Gallegos      AR -51.6226  -69.2181     59.00        25           0
# 9      Vung Tau      VN  10.3460  107.0843     79.34        82          40
#
#    Wind Speed Current Description
# 0        3.00    scattered clouds
# 1       18.41           clear sky
# 2        3.00     overcast clouds
# 3        2.30     overcast clouds
# 4       13.80           clear sky
# 5       29.93    scattered clouds
# 6        6.58     overcast clouds
# 7       18.41       broken clouds
# 8       18.41           clear sky
# 9       14.27    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
